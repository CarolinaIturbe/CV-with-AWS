# %%
import pandas as pd
import csv

# %% [markdown]
# ## Obtener AWS S3 Object List

# %%
import boto3
from boto3.session import Session

access_key = #Fill in the access key
secret_access_key = #Fill in the access key


session = Session(aws_access_key_id=access_key,
              aws_secret_access_key=secret_access_key)
s3 = session.resource('s3')

my_bucket = s3.Bucket('custom-labels-console-us-east-2-05e6611d2c')

# %%
object_list = []
for my_bucket_object in my_bucket.objects.all():
    object_list.append(my_bucket_object.key)

# %% [markdown]
# ## Cargar AWS S3 Object List desde file

# %%
object_df=pd.read_csv('C:/Fotointrepretacion_Torreon/ML_results_ALL/full_list.csv', header=None)

# %%
object_list = object_df[0].tolist()
object_list[1:50]
# Out:
# ['15_09_22/copiloto/0006fd55-99c5-4f0a-bf22-24cf7af01412.jpg',
#  '15_09_22/copiloto/000a1216-8f6e-402a-9a50-350c30c6ee4c.jpg',
#  '15_09_22/copiloto/000d810d-f9e9-4e04-9dd5-d1ae61adeeca.jpg',
#  '15_09_22/copiloto/0011fc8c-52dd-471a-8f54-11ded6ec3032.jpg',
#  '15_09_22/copiloto/0015ed34-d462-4938-9fa4-73c9eee62668.jpg',
#  '15_09_22/copiloto/00168e5a-7ccb-4b67-893f-6c90c896ab36.jpg',
#  '15_09_22/copiloto/00195a3d-8341-4b10-8ac8-4db213f4069f.jpg',
#  '15_09_22/copiloto/001c1f30-4365-45ca-9617-5ef7ca1d47f5.jpg',
#  '15_09_22/copiloto/001db5b8-a3bb-42f4-905f-1cea6ca949ae.jpg',
#  '15_09_22/copiloto/002cc0cf-9c30-4386-96dc-8c3103311aab.jpg',
#  '15_09_22/copiloto/003a8dba-7aaf-4728-8a9e-e31b88525516.jpg',
#  '15_09_22/copiloto/00413f2d-2b1e-4dc2-b52d-b58e82779c46.jpg',
#  '15_09_22/copiloto/0045c90e-7ac4-491b-a0f7-ee39639ff364.jpg',
#  '15_09_22/copiloto/004b42c5-f1a8-4475-94ff-0c7b822b32fc.jpg',
#  '15_09_22/copiloto/004ebee6-e142-43c0-995b-795f0a0145c7.jpg',
# ...

# %%
#Lista de objectos JPG con S3 URL
jpg_object =[]
for object in object_list:
    if object.endswith(".json"):
        continue
    jpg_object.append(object)

# %%
# Lista de objetos JPG SOLO con nombre de archivo
jpg_file = []
for object in jpg_object:

    jpg_file.append(object.split('/')[-1])

# %%
len(jpg_file)
# Out:
# 835710

# %%
S3_bucket = pd.DataFrame({'file_name':jpg_file, 's3_key' :jpg_object})
S3_bucket = S3_bucket.drop_duplicates(subset=["file_name"], keep='first')
S3_bucket.set_index("file_name", inplace=True)

# %%
S3_bucket
# Out:
#                                                                                      s3_key
# file_name
# 0006d430-86e3-45d2-b52d-79e41b3c5a93.jpg  15_09_22/copiloto/0006d430-86e3-45d2-b52d-79e4...
# 0006fd55-99c5-4f0a-bf22-24cf7af01412.jpg  15_09_22/copiloto/0006fd55-99c5-4f0a-bf22-24cf...
# 000a1216-8f6e-402a-9a50-350c30c6ee4c.jpg  15_09_22/copiloto/000a1216-8f6e-402a-9a50-350c...
# 000d810d-f9e9-4e04-9dd5-d1ae61adeeca.jpg  15_09_22/copiloto/000d810d-f9e9-4e04-9dd5-d1ae...
# 0011fc8c-52dd-471a-8f54-11ded6ec3032.jpg  15_09_22/copiloto/0011fc8c-52dd-471a-8f54-11de...
# ...                                                                                     ...
# fff045cd-1f06-4625-a221-2a0189483a7e.jpg  fotos.frentes.fracc.12.22/02_tercera_entrega_f...
# fff23cf2-200a-4679-a1ab-848f05db6955.jpg  fotos.frentes.fracc.12.22/02_tercera_entrega_f...
# fff47dca-7527-4e2d-a179-68ba5035be97.jpg  fotos.frentes.fracc.12.22/02_tercera_entrega_f...
# ...

# %%
frentes_df=pd.read_csv("C:/Fotointrepretacion_Torreon/ML_results_ALL/noFrentesPredios.csv", header = None)
frentes_jpgs = frentes_df[0].tolist()

temp = []
for object in frentes_jpgs:

    temp.append(object.split('.')[0:2]) 

frentes_jpg_name = ["".join([temp[frente][0],'.',temp[frente][1]]) for frente in range(len(frentes_jpgs))]

frentes_dataframe = pd.DataFrame({'frentes_file':frentes_jpg_name})
frentes_dataframe.set_index("frentes_file", inplace=True)
frentes_dataframe
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
frentes_dataframe['s3_key'] = frentes_dataframe.index.map(S3_bucket['s3_key'])
frentes_s3_list = frentes_dataframe['s3_key'].tolist()
frentes_dataframe
# Out:
#                                                                                      s3_key
# frentes_file
# 00a3846d-8afd-433a-87a0-aead3a5f152b.jpg  fotos.frentes.16.09.22/16_09/piloto/00a3846d-8...
# 00ad405c-496b-4731-bf38-b413fdd73d12.jpg  fotos.frentes.22.09.22/22_09/piloto/00ad405c-4...
# 00afcc96-1844-407c-8a84-0f05d25ba355.jpg  fotos.frentes.20.09.22/20_09/piloto/00afcc96-1...
# 00b848e4-340b-4560-931a-9f6a52f3becf.jpg  fotos.frentes.01.10.22/01_10/piloto/00b848e4-3...
# 00bee094-8a98-4e03-9875-dc5c1ef1da78.jpg  fotos.frentes.04.10.22/04_10/piloto/00bee094-8...
# ...                                                                                     ...
# 00000f7f-29ea-4610-a59b-db8ee9f2a6cc.jpg  fotos.frentes.18.09.22/18_09/copiloto/00000f7f...
# 000b10b9-faa8-405a-a1f9-b22ecec3e7b2.jpg  fotos.frentes.23.09.22/23_09/copiloto/000b10b9...
# 000c1ab7-f94d-4200-ab36-96300c1d9b06.jpg  fotos.frentes.05.10.22/05_10/copiloto/000c1ab7...
# ...

# %%
frentes_dataframe.to_csv("C:/Fotointrepretacion_Torreon/ML_results_ALL/pathS3_nofrentesPredios.csv")

# %% [markdown]
# ## Copiar a AWS rekognition folder para clasificar

# %%
keys_frentes=pd.read_csv("C:/Fotointrepretacion_Torreon/ML_results_ALL/pathS3_nofrentesPredios.csv")

keys_frentes.set_index("frentes_file", inplace=True)

keys_frentes
# Out:
#                                                                                      s3_key
# frentes_file
# 00a3846d-8afd-433a-87a0-aead3a5f152b.jpg  fotos.frentes.16.09.22/16_09/piloto/00a3846d-8...
# 00ad405c-496b-4731-bf38-b413fdd73d12.jpg  fotos.frentes.22.09.22/22_09/piloto/00ad405c-4...
# 00afcc96-1844-407c-8a84-0f05d25ba355.jpg  fotos.frentes.20.09.22/20_09/piloto/00afcc96-1...
# 00b848e4-340b-4560-931a-9f6a52f3becf.jpg  fotos.frentes.01.10.22/01_10/piloto/00b848e4-3...
# 00bee094-8a98-4e03-9875-dc5c1ef1da78.jpg  fotos.frentes.04.10.22/04_10/piloto/00bee094-8...
# ...                                                                                     ...
# 00000f7f-29ea-4610-a59b-db8ee9f2a6cc.jpg  fotos.frentes.18.09.22/18_09/copiloto/00000f7f...
# 000b10b9-faa8-405a-a1f9-b22ecec3e7b2.jpg  fotos.frentes.23.09.22/23_09/copiloto/000b10b9...
# 000c1ab7-f94d-4200-ab36-96300c1d9b06.jpg  fotos.frentes.05.10.22/05_10/copiloto/000c1ab7...
# ...

# %%
for i in keys_frentes.index:

    copy_source = {
        'Bucket': 'torreon.fotos.frentes.predios',
        'Key': frentes_dataframe['s3_key'][i]
    }
    s3.meta.client.copy(copy_source, 'custom-labels-console-us-east-2-05e6611d2c', 'assets/assets.frentes.torreon.computer.vision.01/no.frentes.predios/'+i)

# %%
import pandas as pd
import boto3
from boto3.session import Session

access_key = 'AKIAVWSZZW3EZUVBDYUY'
secret_access_key = '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'


session = Session(aws_access_key_id=access_key,
              aws_secret_access_key=secret_access_key)

s3 = session.resource('s3')

# %%
path = "C:/Fotointrepretacion_Torreon/06_entregable"

keys_frentes=pd.read_csv("C:/Fotointrepretacion_Torreon/06_entregable/nivelesUno.csv")

keys = keys_frentes['path_aws'].to_list()

# %%
keys[2].split('torreon.fotos.frentes.predios' + '/')[-1]
# Out:
# 'fotos.frentes.17.09.22/17_09/copiloto/15e3bc6b-f105-451e-a132-85d3bcd493c0.jpg'

# %%
i = 0
for key in keys:

    real_key  = keys[i].split('torreon.fotos.frentes.predios' + '/')[-1]
    print(real_key)
    copy_source = {
        'Bucket': 'torreon.fotos.frentes.predios',
        'Key': real_key
    }

    object = real_key.split('/')[-1]
    s3.meta.client.copy(copy_source, 'custom-labels-console-us-east-2-05e6611d2c', 'assets/assets.niveles.construccion.torreon.computer.vision.01/1.nivel/' + object)
    i = i+1
# Out:
# fotos.frentes.17.09.22/17_09/copiloto/2d8250eb-a87a-4e5e-a3ba-43d376e745fc.jpg
# fotos.frentes.17.09.22/17_09/copiloto/1eec5bb2-0e5b-4ba9-aab7-174c65388bd4.jpg
# fotos.frentes.17.09.22/17_09/copiloto/15e3bc6b-f105-451e-a132-85d3bcd493c0.jpg
# fotos.frentes.17.09.22/17_09/copiloto/5e9083c0-0f11-4684-b669-f95881172c0a.jpg
# fotos.frentes.17.09.22/17_09/copiloto/b762cd31-bb70-420d-9566-8cf16a6aac71.jpg
# fotos.frentes.17.09.22/17_09/copiloto/9eaf1518-531e-43b3-be30-e4cdc0ed8cc5.jpg
# fotos.frentes.17.09.22/17_09/copiloto/a5b8946f-c37f-4e6f-ae4a-f09b5cca6735.jpg
# fotos.frentes.17.09.22/17_09/copiloto/832e8005-1e05-4b09-b011-a445dd814ebd.jpg
# fotos.frentes.17.09.22/17_09/copiloto/15b5e629-aa40-4f50-a1d8-5afc71474d0b.jpg
# fotos.frentes.17.09.22/17_09/copiloto/12871ca7-3473-420b-acc8-e002c6187d52.jpg
# fotos.frentes.17.09.22/17_09/copiloto/03b561f0-2942-4b2f-9a88-6351e49da6ad.jpg
# fotos.frentes.17.09.22/17_09/copiloto/052b55f5-6f85-4d07-bb4b-22007dcd7cfc.jpg
# ...

# %% [markdown]
# # Dividir lista en batches

# %%
frentes = pd.read_csv("C:/Fotointrepretacion_Torreon/ML_results_ALL/results/result_all.csv", header = None)

frentes.head()
# Out:
#                     0          1  \
# 0  no.frentes.predios  99.540001
# 1  no.frentes.predios  74.972000
# 2     frentes.predios  99.568001
# 3     frentes.predios  89.473999
# 4  no.frentes.predios  99.880997
#
#                                                    2
# 0  15_09_22/copiloto/0006d430-86e3-45d2-b52d-79e4...
# 1  15_09_22/copiloto/0006fd55-99c5-4f0a-bf22-24cf...
# 2  15_09_22/copiloto/000a1216-8f6e-402a-9a50-350c...
# 3  15_09_22/copiloto/000d810d-f9e9-4e04-9dd5-d1ae...
# 4  15_09_22/copiloto/0011fc8c-52dd-471a-8f54-11de...

# %%
frentes_predios = frentes[frentes[0] == 'frentes.predios']
frentes_predios
# Out:
#                       0          1  \
# 2       frentes.predios  99.568001
# 3       frentes.predios  89.473999
# 8       frentes.predios  90.622002
# 9       frentes.predios  99.276001
# 10      frentes.predios  90.959000
# ...                 ...        ...
# 825421  frentes.predios  96.267006
# 825432  frentes.predios  94.388000
# 825437  frentes.predios  75.663002
# 825439  frentes.predios  91.949997
# 825440  frentes.predios  95.298996
#
#                                                         2
# 2       15_09_22/copiloto/000a1216-8f6e-402a-9a50-350c...
# 3       15_09_22/copiloto/000d810d-f9e9-4e04-9dd5-d1ae...
# 8       15_09_22/copiloto/001c1f30-4365-45ca-9617-5ef7...
# 9       15_09_22/copiloto/001db5b8-a3bb-42f4-905f-1cea...
# 10      15_09_22/copiloto/002cc0cf-9c30-4386-96dc-8c31...
# ...                                                   ...
# 825421  fotos.frentes.fracc.12.22/02_tercera_entrega_f...
# 825432  fotos.frentes.fracc.12.22/02_tercera_entrega_f...
# ...

# %%
keys_frentes_predios = frentes_predios[2]
list_keys_frentes = keys_frentes_predios.to_list()

# %%
def divide_chunks(l, n):

    k, m = divmod(len(l), n)
    return (l[i*k+min(i, m):(i+1)*k+min(i+1, m)] for i in range(n))
 
 
batches = list(divide_chunks(list_keys_frentes, 20))

# %%
for i in range(len(batches)):

    with open(f'C:/Fotointrepretacion_Torreon/ML_results_ALL/06_entregable/batches/batch_{i}.txt', 'w') as f:
      
        # using csv.writer method from CSV package
        write = csv.writer(f)
        
        #write.writerow(fields)
        write.writerows(batches[i])
